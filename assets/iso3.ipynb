# %%
import requests
import pandas as pd
import json


data = requests.get('https://disease.sh/v3/covid-19/countries')
data = json.loads(data.text)
df = pd.json_normalize(data)
# Out:
#          updated      country   cases  todayCases  deaths  todayDeaths  \
# 0  1643725724068  Afghanistan  163555         629    7417            3
# 1  1643725723978      Albania  258573           0    3346            0
# 2  1643725724061      Algeria  252117           0    6579            0
# 3  1643725724260      Andorra   35958           0     145            0
# 4  1643725724082       Angola   98116           0    1895            0
#
#    recovered  todayRecovered  active  critical  ...  oneTestPerPeople  \
# 0     146608              31    9530      1124  ...                47
# 1     236440               0   18787        23  ...                 2
# 2     167715               0   77823        32  ...               195
# 3      32097               0    3716        14  ...                 0
# 4      94978               0    1243         8  ...                25
#
#    activePerOneMillion  recoveredPerOneMillion  criticalPerOneMillion  \
# ...

# %%
data = df.loc[:,['countryInfo.iso3', 'country']]
data.values
# Out:
# array([['AFG', 'Afghanistan'],
#        ['ALB', 'Albania'],
#        ['DZA', 'Algeria'],
#        ['AND', 'Andorra'],
#        ['AGO', 'Angola'],
#        ['AIA', 'Anguilla'],
#        ['ATG', 'Antigua and Barbuda'],
#        ['ARG', 'Argentina'],
#        ['ARM', 'Armenia'],
#        ['ABW', 'Aruba'],
#        ['AUS', 'Australia'],
#        ['AUT', 'Austria'],
#        ['AZE', 'Azerbaijan'],
#        ['BHS', 'Bahamas'],
#        ['BHR', 'Bahrain'],
#        ['BGD', 'Bangladesh'],
#        ['BRB', 'Barbados'],
#        ['BLR', 'Belarus'],
#        ['BEL', 'Belgium'],
#        ['BLZ', 'Belize'],
#        ['BEN', 'Benin'],
#        ['BMU', 'Bermuda'],
#        ['BTN', 'Bhutan'],
#        ['BOL', 'Bolivia'],
#        ['BIH', 'Bosnia'],
#        ['BWA', 'Botswana'],
#        ['BRA', 'Brazil'],
#        ['VGB', 'British Virgin Islands'],
#        ['BRN', 'Brunei'],
#        ['BGR', 'Bulgaria'],
#        ['BFA', 'Burkina Faso'],
#        ['BDI', 'Burundi'],
#        ['CPV', 'Cabo Verde'],
# ...
